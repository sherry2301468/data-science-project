# %% [markdown]
# # Phase 6: Deployment
#
# **CRISP-DM Phase Description:**
# The final phase involves organising and presenting the project findings so that the customer can use them, or integrating the model into a live production system. Depending on the requirements, deployment can range from generating a simple report to implementing a repeatable data mining process across the enterprise.
#
# ---

# %%
# Standard imports
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ### Task 1: Plan Deployment
#
# Develop a strategy for putting the data mining results to practical use. This includes:
#
# - **Deployment Strategy:** How will the model be consumed? Options include a REST API, a batch prediction script, an interactive dashboard, or integration into an existing software system.
# - **Infrastructure Requirements:** What technical environment is needed (e.g., cloud services, web server, containerisation)?
# - **Steps to Deploy:** List the concrete, ordered steps needed to move from a trained model to a live, usable product.
# - **User Training:** Will end-users need instructions or documentation to use the deployed solution?
#
# **Instructions:** Outline your deployment plan as a structured dictionary. If building an API or script, sketch the basic structure in code.

# %%
# TODO: Plan the deployment of your model/solution.

deployment_plan = {
    "strategy": "Batch prediction system integrated into an analytical dashboard or reporting workflow",

    "infrastructure": [
        "Python runtime environment",
        "Saved trained model file (e.g., joblib/pickle)",
        "Prepared input data pipeline",
        "Dashboard or reporting interface for analysts"
    ],

    "deployment_steps": [
        "Step 1: Save the trained Random Forest model and preprocessing outputs",
        "Step 2: Load new crime records into the prepared input format",
        "Step 3: Run the model on new input data to generate crime type predictions",
        "Step 4: Store the predictions in a report or dashboard",
        "Step 5: Review outputs regularly and retrain the model when performance declines"
    ],

    "intended_users": [
        "Crime analysts",
        "Researchers",
        "Law enforcement planning teams"
    ],

    "business_value": "The deployed model can support trend analysis and help identify likely crime categories from temporal and spatial information."
}

# %%
# Optional: Sketch a basic deployment script or API structure
# Example deployment-oriented prediction function
def predict_crime_type(model, input_df):
    """
    Takes prepared feature data and returns predicted crime type labels.
    """
    predictions = model.predict(input_df)
    return predictions

print("A simple batch prediction function has been defined for deployment planning.")
# Out:
# A simple batch prediction function has been defined for deployment planning.

# %%
# Display the deployment plan
print(json.dumps(deployment_plan, indent=2))
# Out:
# {
#   "strategy": "Batch prediction system integrated into an analytical dashboard or reporting workflow",
#   "infrastructure": [
#     "Python runtime environment",
#     "Saved trained model file (e.g., joblib/pickle)",
#     "Prepared input data pipeline",
#     "Dashboard or reporting interface for analysts"
#   ],
#   "deployment_steps": [
#     "Step 1: Save the trained Random Forest model and preprocessing outputs",
#     "Step 2: Load new crime records into the prepared input format",
#     "Step 3: Run the model on new input data to generate crime type predictions",
#     "Step 4: Store the predictions in a report or dashboard",
#     "Step 5: Review outputs regularly and retrain the model when performance declines"
#   ],
#   "intended_users": [
#     "Crime analysts",
#     "Researchers",
#     "Law enforcement planning teams"
#   ],
#   "business_value": "The deployed model can support trend analysis and help identify likely crime categories from temporal and spatial information."
# }

# %% [markdown]
# ---
# ### Task 2: Plan Monitoring and Maintenance
#
# A deployed model is not "set and forget". Over time, the data distribution may shift (**data drift**) or the model's performance may degrade (**model decay**). This task creates a monitoring and maintenance plan:
#
# - **Performance Monitoring:** How and how often will the model's predictions be evaluated against actuals?
# - **Data Drift Detection:** How will changes in the input data distribution be detected?
# - **Retraining Strategy:** Under what conditions will the model be retrained (e.g., scheduled, triggered by performance drop)?
# - **Logging and Alerting:** What will be logged, and what triggers an alert?
#
# **Instructions:** Document your monitoring and maintenance plan.

# %%
# TODO: Plan monitoring and maintenance.

monitoring_plan = {
    "performance_monitoring": {
        "frequency": "Monthly",
        "metrics_tracked": ["Accuracy", "Precision", "Recall", "Weighted F1-Score"],
        "method": "Compare predictions against actual observed crime types when new labelled data becomes available"
    },

    "data_drift_detection": {
        "method": "Monitor changes in distributions of key input features such as district, beat, hour, and month",
        "frequency": "Monthly",
        "threshold": "Investigate if significant shifts are observed compared with the training data"
    },

    "retraining_strategy": {
        "trigger": "Retrain when weighted F1-score declines consistently or when major data drift is detected",
        "frequency": "Quarterly or when enough new labelled data is collected"
    },

    "maintenance_tasks": [
        "Check model performance regularly",
        "Validate new incoming data format",
        "Investigate error patterns on rare crime types",
        "Update the model and documentation when retraining occurs"
    ]
}

# %%
# Display the monitoring plan
print(json.dumps(monitoring_plan, indent=2))
# Out:
# {
#   "performance_monitoring": {
#     "frequency": "Monthly",
#     "metrics_tracked": [
#       "Accuracy",
#       "Precision",
#       "Recall",
#       "Weighted F1-Score"
#     ],
#     "method": "Compare predictions against actual observed crime types when new labelled data becomes available"
#   },
#   "data_drift_detection": {
#     "method": "Monitor changes in distributions of key input features such as district, beat, hour, and month",
#     "frequency": "Monthly",
#     "threshold": "Investigate if significant shifts are observed compared with the training data"
#   },
#   "retraining_strategy": {
#     "trigger": "Retrain when weighted F1-score declines consistently or when major data drift is detected",
#     "frequency": "Quarterly or when enough new labelled data is collected"
#   },
#   "maintenance_tasks": [
#     "Check model performance regularly",
#     "Validate new incoming data format",
#     "Investigate error patterns on rare crime types",
#     "Update the model and documentation when retraining occurs"
#   ]
# }

# %% [markdown]
# ---
# ### Task 3: Produce Final Report
#
# Compile a final summary of the entire project. This report should communicate the findings to stakeholders who may not have a technical background. It typically includes:
#
# - **Executive Summary:** A brief overview of the problem, approach, and key results.
# - **Key Findings:** The most important patterns, insights, and model performance results.
# - **Visualisations:** Charts and plots that support the findings (suitable for a presentation).
# - **Recommendations:** Actionable recommendations based on the analysis.
# - **Limitations:** Known limitations and caveats of the analysis.
#
# **Instructions:** Draft the final report content below. Include any code needed to generate summary visualisations.

# %%
# TODO: Draft the final report as a structured document.

final_report = {
    "title": "Crime Type Prediction using Chicago Crime Data",

    "executive_summary": (
        "This project applied the CRISP-DM methodology to predict crime type using "
        "Chicago crime data. The workflow included business understanding, data understanding, "
        "data preparation, model training, evaluation, and deployment planning. A Random Forest "
        "model achieved the best overall performance, although the problem remains challenging due "
        "to class imbalance and the large number of target categories."
    ),

    "key_findings": [
        "Crime type prediction is a difficult multi-class classification problem",
        "Temporal and spatial features such as hour, day, district, and beat are useful predictors",
        "Random Forest outperformed Logistic Regression",
        "Model performance was stable across cross-validation folds",
        "Class imbalance reduced performance on less frequent crime categories"
    ],

    "model_performance": {
        "best_model": "Random Forest",
        "key_metric": "Weighted F1-Score",
        "key_metric_value": 0.3138
    },

    "recommendations": [
        "Use the model for analytical support rather than high-stakes operational decisions",
        "Incorporate additional features such as socio-economic or environmental data",
        "Apply stronger class imbalance handling methods",
        "Test more advanced models such as XGBoost"
    ],

    "limitations": [
        "Moderate predictive performance",
        "Class imbalance across crime categories",
        "Limited feature set",
        "Simplified treatment of complex spatial and temporal dynamics"
    ]
}

# %%
# Display the final report
print("=" * 60)
print(f"FINAL REPORT: {final_report['title']}")
print("=" * 60)

print(f"\n--- Executive Summary ---")
print(final_report['executive_summary'])

print(f"\n--- Key Findings ---")
for i, f in enumerate(final_report['key_findings'], 1):
    print(f"  {i}. {f}")

print(f"\n--- Model Performance ---")
for k, v in final_report["model_performance"].items():
    print(f"{k}: {v}")

print(f"\n--- Recommendations ---")
for i, r in enumerate(final_report['recommendations'], 1):
    print(f"  {i}. {r}")

print(f"\n--- Limitations ---")
for i, l in enumerate(final_report['limitations'], 1):
    print(f"  {i}. {l}")
# Out:
# ============================================================
# FINAL REPORT: Crime Type Prediction using Chicago Crime Data
# ============================================================
#
# --- Executive Summary ---
# This project applied the CRISP-DM methodology to predict crime type using Chicago crime data. The workflow included business understanding, data understanding, data preparation, model training, evaluation, and deployment planning. A Random Forest model achieved the best overall performance, although the problem remains challenging due to class imbalance and the large number of target categories.
#
# --- Key Findings ---
#   1. Crime type prediction is a difficult multi-class classification problem
#   2. Temporal and spatial features such as hour, day, district, and beat are useful predictors
#   3. Random Forest outperformed Logistic Regression
#   4. Model performance was stable across cross-validation folds
#   5. Class imbalance reduced performance on less frequent crime categories
#
# --- Model Performance ---
# best_model: Random Forest
# key_metric: Weighted F1-Score
# key_metric_value: 0.3138
#
# --- Recommendations ---
#   1. Use the model for analytical support rather than high-stakes operational decisions
#   2. Incorporate additional features such as socio-economic or environmental data
#   3. Apply stronger class imbalance handling methods
#   4. Test more advanced models such as XGBoost
#
# --- Limitations ---
#   1. Moderate predictive performance
#   2. Class imbalance across crime categories
#   3. Limited feature set
#   4. Simplified treatment of complex spatial and temporal dynamics

# %%
# Optional: Generate summary visualisations for the stakeholder presentation
# Recreate model comparison using results from Phase 4

results_summary = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Random Forest",
        "Random Forest (Tuned)"
    ],
    "F1-Score": [
        0.28,
        0.30,
        0.3138
    ]
})

models = results_summary["Model"]
scores = results_summary["F1-Score"]

plt.figure(figsize=(8, 5))
plt.bar(models, scores)
plt.title("Model Performance Comparison")
plt.ylabel("Weighted F1-Score")
plt.ylim(0, max(scores) + 0.05)
plt.xticks(rotation=15)
plt.show()

# %% [markdown]
# ---
# ### Task 4: Review Project
#
# Conduct a project retrospective. Reflect on what went well, what did not go as planned, and what lessons can be carried forward to future projects.
#
# - **What went well?** Successes, effective techniques, good decisions.
# - **What could be improved?** Challenges, mistakes, or inefficiencies encountered.
# - **Lessons learned:** Key takeaways for future data science projects.
# - **Skills developed:** New skills or knowledge gained during the project.
#
# **Instructions:** Complete the project retrospective below.

# %%
# TODO: Conduct the project retrospective.

project_retrospective = {
    "went_well": [
        "The CRISP-DM workflow provided a clear structure for the project",
        "Data preparation successfully produced a clean modelling dataset",
        "Model comparison and cross-validation gave a reliable evaluation framework",
        "Random Forest improved performance over the baseline model"
    ],

    "could_improve": [
        "More external features could have been included",
        "Class imbalance should have been addressed more aggressively",
        "The modelling phase could be expanded with additional algorithms"
    ],

    "lessons_learned": [
        "Real-world multi-class classification problems can be difficult even with substantial data",
        "Feature engineering has a major impact on model quality",
        "Evaluation should focus on appropriate metrics such as weighted F1-score for imbalanced problems"
    ],

    "skills_developed": [
        "Data cleaning and feature engineering",
        "Model training and comparison",
        "Hyperparameter tuning with GridSearchCV",
        "Cross-validation and model evaluation",
        "Communicating results through CRISP-DM documentation"
    ]
}

# %%
# Display the retrospective
print("=" * 60)
print("PROJECT RETROSPECTIVE")
print("=" * 60)

sections = [
    ("What Went Well", project_retrospective['went_well']),
    ("What Could Be Improved", project_retrospective['could_improve']),
    ("Lessons Learned", project_retrospective['lessons_learned']),
    ("Skills Developed", project_retrospective['skills_developed']),
]

for section_name, items in sections:
    print(f"\n--- {section_name} ---")
    if items:
        for i, item in enumerate(items, 1):
            print(f"{i}. {item}")
    else:
        print("No items recorded.")
# Out:
# ============================================================
# PROJECT RETROSPECTIVE
# ============================================================
#
# --- What Went Well ---
# 1. The CRISP-DM workflow provided a clear structure for the project
# 2. Data preparation successfully produced a clean modelling dataset
# 3. Model comparison and cross-validation gave a reliable evaluation framework
# 4. Random Forest improved performance over the baseline model
#
# --- What Could Be Improved ---
# 1. More external features could have been included
# 2. Class imbalance should have been addressed more aggressively
# 3. The modelling phase could be expanded with additional algorithms
#
# --- Lessons Learned ---
# 1. Real-world multi-class classification problems can be difficult even with substantial data
# 2. Feature engineering has a major impact on model quality
# 3. Evaluation should focus on appropriate metrics such as weighted F1-score for imbalanced problems
#
# --- Skills Developed ---
# 1. Data cleaning and feature engineering
# 2. Model training and comparison
# 3. Hyperparameter tuning with GridSearchCV
# 4. Cross-validation and model evaluation
# 5. Communicating results through CRISP-DM documentation

# %% [markdown]
# The relatively modest performance highlights the inherent difficulty of multi-class classification in real-world crime datasets.

# %% [markdown]
# ---
#
# ## Key Takeaway on Iteration
#
# While the six CRISP-DM phases are presented **sequentially** in these notebooks, in practice the process is **highly iterative**. Real-world data science projects rarely follow a straight line from Phase 1 to Phase 6.
#
# Common iteration patterns include:
#
# - **Modelling → Data Preparation:** If the model performs poorly, you may return to Phase 3 to engineer new features, clean data differently, or acquire more data.
# - **Evaluation → Modelling:** If the model does not meet the business success criteria, you may go back to Phase 4 to try different algorithms or tune hyperparameters.
# - **Deployment → Evaluation:** If the deployed model underperforms in production (data drift), you may return to Phase 5 to re-evaluate and then to Phase 3/4 to retrain.
# - **Any Phase → Business Understanding:** New findings in later phases may redefine the business objectives or success criteria originally set in Phase 1.
#
# ```
# ┌───────────────────────────────────────────────────────────┐
# │                     CRISP-DM Lifecycle                    │
# │                                                           │
# │   Phase 1 ──► Phase 2 ──► Phase 3 ──► Phase 4            │
# │   Business    Data        Data        Modelling           │
# │   Under.      Under.      Prep.           │               │
# │     ▲                       ▲              │               │
# │     │                       │              ▼               │
# │     │                       └──────── Phase 5             │
# │     │                                Evaluation           │
# │     │                                    │                │
# │     │                                    ▼                │
# │     └──────────────────────────────  Phase 6              │
# │                                     Deployment            │
# └───────────────────────────────────────────────────────────┘
# ```
#
# > **Remember:** Iteration is not failure — it is the *expected* workflow. Each cycle through the process deepens your understanding of both the data and the business problem, ultimately leading to a better solution.
